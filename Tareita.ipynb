# %%
print("""
Tareita

1. Ver tareas
2. Agregar tarea
3. Eliminar tarea
4. Salir
""")

while
tareas = ["Matematicas", "Ingles"]
opcion = int(input("Ingresa la opcion que deseas usar "))


while opcion < 4:
  opcion_elegida = opcion
  match opcion:
    case 1:
      for elegir in opcion:
        print("Hablame")
      print("Tienes estas tareas: ", tareas)
    case 2:
      print("Que tarea deseas agregar", tareas)
    case 3:
      print("¿Que tarea vas a eliminar?", tareas)
    case _:
      print("Saliste del programa")
  break
# Out:
#   File "<tokenize>", line 20
#     print("Tienes estas tareas: ", tareas)
#     ^
# IndentationError: unindent does not match any outer indentation level
